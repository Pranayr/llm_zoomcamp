# %%
print(123)
# Out:
# 123

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from openai import OpenAI
# ----> 2 openai_client = OpenAI()
#
# File /workspaces/llm_zoomcamp/.venv/lib/python3.12/site-packages/openai/_client.py:194, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     185 self.admin_api_key = admin_api_key
#     187 if (
#     188     _enforce_credentials
#     189     and not self.api_key
#    (...)    192     and self.admin_api_key is None
#     193 ):
# --> 194     raise OpenAIError(
# ...
